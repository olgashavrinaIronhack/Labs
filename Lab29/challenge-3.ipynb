# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Challenge-3" data-toc-modified-id="Challenge-3-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Challenge 3</a></span><ul class="toc-item"><li><span><a href="#Q1:-How-to-identify-VIP-&amp;-Preferred-Customers?" data-toc-modified-id="Q1:-How-to-identify-VIP-&amp;-Preferred-Customers?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Q1: How to identify VIP &amp; Preferred Customers?</a></span></li><li><span><a href="#How-to-label-customers-whose-aggregated-amount_spent-is-in-a-given-quantile-range?" data-toc-modified-id="How-to-label-customers-whose-aggregated-amount_spent-is-in-a-given-quantile-range?-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>How to label customers whose aggregated <code>amount_spent</code> is in a given quantile range?</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Sub-Problem-1:-How-to-aggregate-the--amount_spent-for-unique-customers?" data-toc-modified-id="Sub-Problem-1:-How-to-aggregate-the--amount_spent-for-unique-customers?-1.2.0.1"><span class="toc-item-num">1.2.0.1&nbsp;&nbsp;</span>Sub Problem 1: How to aggregate the  <code>amount_spent</code> for unique customers?</a></span></li><li><span><a href="#Sub-Problem-2:-How-to-select-customers-whose-aggregated-amount_spent-is-in-a-given-quantile-range?" data-toc-modified-id="Sub-Problem-2:-How-to-select-customers-whose-aggregated-amount_spent-is-in-a-given-quantile-range?-1.2.0.2"><span class="toc-item-num">1.2.0.2&nbsp;&nbsp;</span>Sub Problem 2: How to select customers whose aggregated <code>amount_spent</code> is in a given quantile range?</a></span></li><li><span><a href="#Sub-Problem-3:-How-to-label-selected-customers-as-&quot;VIP&quot;-or-&quot;Preferred&quot;?" data-toc-modified-id="Sub-Problem-3:-How-to-label-selected-customers-as-&quot;VIP&quot;-or-&quot;Preferred&quot;?-1.2.0.3"><span class="toc-item-num">1.2.0.3&nbsp;&nbsp;</span>Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?</a></span></li></ul></li></ul></li><li><span><a href="#Q2:-How-to-identify-which-country-has-the-most-VIP-Customers?" data-toc-modified-id="Q2:-How-to-identify-which-country-has-the-most-VIP-Customers?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Q2: How to identify which country has the most VIP Customers?</a></span></li><li><span><a href="#Q3:-How-to-identify-which-country-has-the-most-VIP+Preferred-Customers-combined?" data-toc-modified-id="Q3:-How-to-identify-which-country-has-the-most-VIP+Preferred-Customers-combined?-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Q3: How to identify which country has the most VIP+Preferred Customers combined?</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set (https://drive.google.com/file/d/1xUzMpyQgC5IaK61ehUH2C5P4jCPmLa-s/view?usp=sharing). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Data Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders` from Ironhack's database into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# your code here
orders=pd.read_csv(r'D:/Téléchargements/orders.csv')
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
# 5         set 7 babushka nesting boxes         2  2010-12-01 08:26:00
# 6    glass star frosted t-light holder         6  2010-12-01 08:26:00
# 7               hand warmer union jack         6  2010-12-01 08:28:00
# 8            hand warmer red polka dot         6  2010-12-01 08:28:00
# 9        assorted colour bird ornament        32  2010-12-01 08:34:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34
# 5       7.65       17850  United Kingdom         15.30
# 6       4.25       17850  United Kingdom         25.50
# 7       1.85       17850  United Kingdom         11.10
# 8       1.85       17850  United Kingdom         11.10
# 9       1.69       13047  United Kingdom         54.08

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
amount_spent = orders.groupby('CustomerID', as_index=False).agg({'amount_spent':'sum'}).sort_values(['amount_spent'],ascending=False)
amount_spent
# Out:
#       CustomerID  amount_spent
# 1690       14646     280206.02
# 4202       18102     259657.30
# 3729       17450     194550.79
# 3009       16446     168472.50
# 1880       14911     143825.06
# ...          ...           ...
# 4099       17956         12.75
# 3015       16454          6.90
# 1794       14792          6.20
# 3218       16738          3.75
# 685        13256          0.00
#
# [4339 rows x 2 columns]

# %%
amount_spent.quantile(q=0.95, axis=0, numeric_only=True, interpolation='linear')
# Out:
# CustomerID      17984.100
# amount_spent     5840.182
# Name: 0.95, dtype: float64

# %%
amount_spent.describe()
# Out:
#          CustomerID   amount_spent
# count   4339.000000    4339.000000
# mean   15299.936852    2053.793018
# std     1721.889758    8988.248381
# min    12346.000000       0.000000
# 25%    13812.500000     307.245000
# 50%    15299.000000     674.450000
# 75%    16778.500000    1661.640000
# max    18287.000000  280206.020000

# %%
amount_spent.max()
# Out:
# CustomerID          18287
# amount_spent    280206.02
# cust_type             VIP
# dtype: object

# %%
cutoffs = [0,1661.640000,5840.182,300000]
cust_labels=['Occasional','Preferred','VIP']
amount_spent['cust_type'] = pd.cut(amount_spent['amount_spent'],cutoffs, labels=cust_labels)
amount_spent
# Out:
#       CustomerID  amount_spent   cust_type
# 1690       14646     280206.02         VIP
# 4202       18102     259657.30         VIP
# 3729       17450     194550.79         VIP
# 3009       16446     168472.50         VIP
# 1880       14911     143825.06         VIP
# ...          ...           ...         ...
# 4099       17956         12.75  Occasional
# 3015       16454          6.90  Occasional
# 1794       14792          6.20  Occasional
# 3218       16738          3.75  Occasional
# 685        13256          0.00         NaN
#
# [4339 rows x 3 columns]

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
orders=pd.merge(orders,amount_spent, on='CustomerID')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541801     581578     22993  2011     12    5    12
# 397920      541802     581578     22907  2011     12    5    12
# 397921      541803     581578     22908  2011     12    5    12
# 397922      541804     581578     23215  2011     12    5    12
# 397923      541805     581578     22736  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3       knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4            red woolly hottie white heart.         6  2010-12-01 08:26:00
# ...                                     ...       ...                  ...
# 397919         set of 4 pantry jelly moulds        12  2011-12-09 12:16:00
# 397920     pack of 20 napkins pantry design        12  2011-12-09 12:16:00
# 397921        pack of 20 napkins red apples        12  2011-12-09 12:16:00
# 397922     jingle bell heart antique silver        12  2011-12-09 12:16:00
# 397923          ribbon reel making snowmen         10  2011-12-09 12:16:00
#
#         UnitPrice  CustomerID         Country  amount_spent_x  amount_spent_y  \
# 0            2.55       17850  United Kingdom           15.30         5391.21
# 1            3.39       17850  United Kingdom           20.34         5391.21
# 2            2.75       17850  United Kingdom           22.00         5391.21
# 3            3.39       17850  United Kingdom           20.34         5391.21
# 4            3.39       17850  United Kingdom           20.34         5391.21
# ...           ...         ...             ...             ...             ...
# 397919       1.25       12713         Germany           15.00          848.55
# 397920       0.85       12713         Germany           10.20          848.55
# 397921       0.85       12713         Germany           10.20          848.55
# 397922       2.08       12713         Germany           24.96          848.55
# 397923       1.65       12713         Germany           16.50          848.55
#
#        cust_type_x  amount_spent cust_type_y
# 0        Preferred       5391.21   Preferred
# 1        Preferred       5391.21   Preferred
# 2        Preferred       5391.21   Preferred
# 3        Preferred       5391.21   Preferred
# 4        Preferred       5391.21   Preferred
# ...            ...           ...         ...
# 397919  Occasional        848.55  Occasional
# 397920  Occasional        848.55  Occasional
# 397921  Occasional        848.55  Occasional
# 397922  Occasional        848.55  Occasional
# 397923  Occasional        848.55  Occasional
#
# [397924 rows x 18 columns]

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
y=pd.get_dummies(orders['cust_type_y'])
y
# Out:
#         Occasional  Preferred  VIP
# 0                0          1    0
# 1                0          1    0
# 2                0          1    0
# 3                0          1    0
# 4                0          1    0
# ...            ...        ...  ...
# 397919           1          0    0
# 397920           1          0    0
# 397921           1          0    0
# 397922           1          0    0
# 397923           1          0    0
#
# [397924 rows x 3 columns]

# %%
orders['Country'] = df['Country'].astype('category')
countries_vip = orders[orders['cust_type_y'] == 'VIP'].groupby(['Country']).size().reset_index(name='count') 
countries_vip
# Out:
#                  Country  count
# 0              Australia    304
# 1                Austria    119
# 2                Bahrain      0
# 3                Belgium    703
# 4                 Brazil     32
# 5                 Canada      6
# 6        Channel Islands    161
# 7                 Cyprus    321
# 8         Czech Republic      0
# 9                Denmark    132
# 10                  EIRE   1754
# 11    European Community      0
# 12               Finland    153
# 13                France   2137
# 14               Germany   2409
# 15                Greece     51
# 16               Iceland     78
# 17                Israel     16
# 18                 Italy    209
# 19                 Japan    144
# 20               Lebanon     10
# 21             Lithuania     35
# 22                 Malta     23
# 23           Netherlands    507
# 24                Norway    325
# 25                Poland    160
# 26              Portugal    299
# 27                   RSA      0
# 28          Saudi Arabia      0
# 29             Singapore     80
# 30                 Spain    634
# 31                Sweden    103
# 32           Switzerland    480
# 33                   USA      0
# 34  United Arab Emirates     30
# 35        United Kingdom  92881
# 36           Unspecified    188

# %%
orders['Country'] = df['Country'].astype('category')
countries_preferred = orders[orders['cust_type_y'] == 'Preferred'].groupby(['Country']).size().reset_index(name='count') 
topcountries=pd.merge(countries_preferred,countries_vip, on='Country')
topcountries['Total']=topcountries['count_x']+topcountries['count_y']
Top5=topcountries.nlargest(5,'Total')
Top5
# Out:
#            Country  count_x  count_y   Total
# 35  United Kingdom   134620    92881  227501
# 14         Germany     3471     2409    5880
# 13          France     3168     2137    5305
# 10            EIRE     2649     1754    4403
# 30           Spain     1002      634    1636
