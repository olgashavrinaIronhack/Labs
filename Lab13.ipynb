# %%
import json
import requests
response=requests.get('https://jsonplaceholder.typicode.com/todos')
response.status_code
results=response.json()
import pandas as pd
data=pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
print(response.status_code)
# Out:
# 200

# %%
response=requests.get('https://api.github.com/events')
data=pd.DataFrame(response.json())
data.head(15)
# Out:
#              id               type  \
# 0   19197540825        CreateEvent
# 1   19197540788          PushEvent
# 2   19197540800          PushEvent
# 3   19197540787          PushEvent
# 4   19197540786         WatchEvent
# 5   19197540778        CreateEvent
# 6   19197540743          PushEvent
# 7   19197540780  IssueCommentEvent
# 8   19197540754          PushEvent
# 9   19197540735         WatchEvent
# 10  19197540733        CreateEvent
# 11  19197540708          PushEvent
# 12  19197540682          PushEvent
# 13  19197540692        CreateEvent
# 14  19197540685         WatchEvent
#
#                                                 actor  \
# 0   {'id': 10786212, 'login': 'marnixah', 'display...
# 1   {'id': 244565, 'login': 'jsarenik', 'display_l...
# 2   {'id': 72747630, 'login': 'geonosis-bot', 'dis...
# 3   {'id': 31848885, 'login': 'atefganm', 'display...
# 4   {'id': 56014108, 'login': 'Feng-Jay', 'display...
# 5   {'id': 41898282, 'login': 'github-actions[bot]...
# ...

# %%
def flatten(data,col_list):
    for column in col_list:
        flattened=pd.DataFrame(dict(data[column])).transpose()
        columns=[str(col) for col in flattened.column]
        flattened.columns=[column+'_'+colname for colname]
# Out:
#   File "<ipython-input-13-d1c48b0bb35b>", line 5
#     flattened.columns=[column+'_'+colname for colname]
#                                                      ^
# SyntaxError: invalid syntax

# %%
results=response.json()
flattened_data=pd.json_normalize(results)
flattened_data
# Out:
#              id               type  public            created_at  actor.id  \
# 0   19197540825        CreateEvent    True  2021-12-06T10:46:37Z  10786212
# 1   19197540788          PushEvent    True  2021-12-06T10:46:37Z    244565
# 2   19197540800          PushEvent    True  2021-12-06T10:46:37Z  72747630
# 3   19197540787          PushEvent    True  2021-12-06T10:46:37Z  31848885
# 4   19197540786         WatchEvent    True  2021-12-06T10:46:37Z  56014108
# 5   19197540778        CreateEvent    True  2021-12-06T10:46:37Z  41898282
# 6   19197540743          PushEvent    True  2021-12-06T10:46:37Z  15682954
# 7   19197540780  IssueCommentEvent    True  2021-12-06T10:46:37Z  95619961
# 8   19197540754          PushEvent    True  2021-12-06T10:46:37Z   3441933
# 9   19197540735         WatchEvent    True  2021-12-06T10:46:37Z  11481643
# 10  19197540733        CreateEvent    True  2021-12-06T10:46:37Z  46379669
# ...

# %%
response=requests.get('https://api.github.com/users/Ironhack/repos')
response.status_code
# Out:
# 200

# %%
results=response.json()

# %%
data=pd.json_normalize(results)
data
# Out:
#            id                           node_id  \
# 0    75170096  MDEwOlJlcG9zaXRvcnk3NTE3MDA5Ng==
# 1   197550983  MDEwOlJlcG9zaXRvcnkxOTc1NTA5ODM=
# 2    57225749  MDEwOlJlcG9zaXRvcnk1NzIyNTc0OQ==
# 3    56848097  MDEwOlJlcG9zaXRvcnk1Njg0ODA5Nw==
# 4   122097049  MDEwOlJlcG9zaXRvcnkxMjIwOTcwNDk=
# 5    96100950  MDEwOlJlcG9zaXRvcnk5NjEwMDk1MA==
# 6    62580111  MDEwOlJlcG9zaXRvcnk2MjU4MDExMQ==
# 7   150108250  MDEwOlJlcG9zaXRvcnkxNTAxMDgyNTA=
# 8    44265416  MDEwOlJlcG9zaXRvcnk0NDI2NTQxNg==
# 9    56841990  MDEwOlJlcG9zaXRvcnk1Njg0MTk5MA==
# 10  134574029  MDEwOlJlcG9zaXRvcnkxMzQ1NzQwMjk=
# 11  115990443  MDEwOlJlcG9zaXRvcnkxMTU5OTA0NDM=
# 12   96104549  MDEwOlJlcG9zaXRvcnk5NjEwNDU0OQ==
# 13   86328286  MDEwOlJlcG9zaXRvcnk4NjMyODI4Ng==
# 14   34860891  MDEwOlJlcG9zaXRvcnkzNDg2MDg5MQ==
# 15  139946618  MDEwOlJlcG9zaXRvcnkxMzk5NDY2MTg=
# 16   85951144  MDEwOlJlcG9zaXRvcnk4NTk1MTE0NA==
# 17   97860064  MDEwOlJlcG9zaXRvcnk5Nzg2MDA2NA==
# ...

# %%
number_of_forks = (data["fork"]==True).count()
print(number_of_forks)
# Out:
# 30

# %%
data['language']
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
data.language.value_counts()
# Out:
# JavaScript    11
# Ruby           4
# HTML           4
# CSS            2
# TSQL           1
# C++            1
# Shell          1
# FreeMarker     1
# TypeScript     1
# Name: language, dtype: int64

# %%
data.forks_count.value_counts().sum()
# Out:
# 30

# %%
data.commits_url.value_counts().sum()
# Out:
# 30

# %%
data.fork.value_counts()
# Out:
# True     17
# False    13
# Name: fork, dtype: int64

# %%
import requests
r=requests.get('https://xkcd.com/1906/')

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2678', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Mon, 06 Dec 2021 05:00:04 GMT', 'ETag': 'W/"61ad98d4-1b1c"', 'Expires': 'Mon, 06 Dec 2021 13:13:18 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 06 Dec 2021 13:14:09 GMT', 'Via': '1.1 varnish', 'Age': '18', 'X-Served-By': 'cache-cdg20724-CDG', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1638796450.936938,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
r.headers['Expires']
# Out:
# 'Mon, 06 Dec 2021 13:13:18 GMT'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Making Progress</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Making Progress">\n<meta property="og:url" content="https://xkcd.com/1906/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/making_progress_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="topContainer">\
# ...

# %%
receive=requests.get('https://imgs.xkcd.com/comics/before_sunrise.png')
with open(r'D:\Téléchargements\before_sunrise.png','wb') as f: 
          f.write(receive.content)

# %%
import requests
ploads={'things':2,'total':25}
r=requests.get('https://httpbin.org/get',params=ploads)
print(r.text)
print(r.url)
# Out:
# {
#   "args": {
#     "things": "2",
#     "total": "25"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae10f6-13176cbb667ba7ff759aa96b"
#   },
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/get?things=2&total=25"
# }
#
# https://httpbin.org/get?things=2&total=25

# %%
import requests
pload={"Username":'Olga','password':'admin'}
r=requests.post('https://httpbin.org/post',data=pload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "Username": "Olga",
#     "password": "admin"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "28",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae13d3-3154aae74c60d50707dc7595"
#   },
#   "json": null,
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests
pload={"Username":'Olga','password':'admin'}
r=requests.post('https://httpbin.org/post',data=pload)
r_dictionary=r.json()
print(r_dictionary['form'])
# Out:
# {'Username': 'Olga', 'password': 'admin'}

# %%
response=requests.get('https://api.github.com/users/ironhack-datalabs/scavenger')
response.status_code
# Out:
# 404

# %%
GET/repos
