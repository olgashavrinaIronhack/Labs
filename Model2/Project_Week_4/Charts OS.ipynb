# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:/Users/oshav/DAFT_NOV_21_01/module_2/Project_Week_4/diamonds_clean.csv')

# %%
data.head(5)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z  clarity_1  color_1   check_z
# 0  2.43          1        5  0.213745
# 1  2.31          2        5  0.032859
# 2  2.31          4        5  0.003448
# 3  2.63          3        1  0.003796
# 4  2.75          1        0  0.008861

# %%
df_1=diamonds_clean[data['carat']<2]

# %%
bins = [0,0.5,1,1.5,2]
plt.hist('carat',data=df_1, bins=bins, histtype='bar', rwidth=0.8)
plt.xlabel('carat')
plt.ylabel('Number of diamonds')
plt.title('Distribution of diamonds per carat')
plt.show()

# %%
df_1_fair = df_1[(df_1['cut'] == 'Fair') ]
df_1_good = df_1[(df_1['cut'] == 'Good') ]
df_1_vgood = df_1[(df_1['cut'] == 'Very Good')]# & (df_1['price'] < 12500)]
df_1_premium = df_1[(df_1['cut'] == 'Premium')]# & (df_1['price'] < 12500)]
df_1_ideal = df_1[(df_1['cut'] == 'Ideal')]# & (df_1['price'] < 12500)]

plt.figure(figsize = [16,10])
plt.boxplot([df_1_fair['price'], df_1_good['price'], df_1_vgood['price'], df_1_premium['price'], df_1_ideal['price']])

plt.xticks((1,2,3,4,5), ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'])

plt.title("Price vs Type of Cut\n", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

plt.xlabel("Type of Cut", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})
plt.ylabel("Price", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})

plt.show()

# %%
plt.scatter(data = data , x = 'carat', y = 'price')
plt.show()

plt.figure(figsize = [14,10])
plt.scatter(data = data , x = 'carat', y = 'price', alpha = 0.5, marker="x")

# Adding and formatting title
plt.title("Weight (in carats) vs Price\n", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

# Labeling Axes
plt.xlabel("Weight (in Carats) ", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})
plt.ylabel("Price", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})

plt.show()

# %%
plt.hist(data["price"], bins = 150)

# Adding and formatting title
plt.title("Frequency Plot: Prices of Diamonds\n", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

plt.xlabel("Price", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})
plt.ylabel("Count", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})

plt.show()

# %%
plt.hexbin(data=data, x='carat',y='price',edgecolors='face')

# %%
plt.figure(figsize=[12,12])

# First subplot showing the diamond carat weight distribution
plt.subplot(221)
plt.hist(data['carat'],bins=20,color='lightseagreen')
plt.xlabel('Carat Weight')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond Carat Weight')

# Second subplot showing the diamond depth distribution
plt.subplot(222)
plt.hist(data['color_1'],bins=20,color='royalblue')
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Distribution of Diamond color scale')

# Third subplot showing the diamond price distribution
plt.subplot(223)
plt.hist(data['price'],bins=20,color='salmon')
plt.xlabel('Price in USD')
plt.ylabel('Frequency')
plt.title('Distribution of Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Price')

# %%
carat = df_1.carat
clarity = df_1.clarity
plt.scatter(clarity, carat)
plt.show()

# %%
for feature in data.dtypes[data.dtypes != object].index:
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    sns.violinplot(x= feature, data= df_1)
    plt.subplot(1, 2, 2)
    sns.boxplot(x= feature, data= df_1)
    plt.show()

# %%
df_1.hist(figsize=(20, 20))
plt.show()

# %%
df=diamonds_clean[['price','carat','color_1','clarity_1']]
corr=df.corr()
sns.heatmap(corr,vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df_1.carat)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Count'>

# %%
sns.histplot(data=df_1,x='price',y='carat',kde=True,hue='color')
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
sns.catplot(x='color', data=df_1 , kind='count',aspect=2.5 )

# %%
grid = sns.FacetGrid(df_1, col="color_1", hue="carat", palette="tab20c")

# %%
g = sns.jointplot(
    data=data,
    x="carat", y="price", 
    kind="kde",
)

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    data,
    x="price", hue="cut",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.set_xticks([500, 1000, 2000, 5000, 10000])

# %%
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_ranking,
              scale="linear", data=data)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='carat'>

# %%
sns.displot(
    data=data, x="price", y="color", col="clarity",
    log_scale=(True, False), col_wrap=4, height=4, aspect=.7,
)
