# %%
pip install stackapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI
import pandas as pd

# %%
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %%
len(comments)
# Out:
# 7

# %% [markdown]
# Question 1: Find the questions and answers of last month.

# %%
#To convert to seconds
from datetime import datetime

#get current date
dt = datetime.today()  
seconds_td = int(dt.timestamp())
seconds_td
# Out:
# 1642002289

# %%
#date last month
t = datetime(2021, 11, 6, 0, 0)
seconds_lm = int(t.timestamp())
seconds_lm
# Out:
# 1636153200

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=seconds_lm, todate=seconds_td)
questions
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# <ipython-input-7-39b13cfd8cb3> in <module>
#       1 from stackapi import StackAPI
#       2 SITE = StackAPI('stackoverflow')
# ----> 3 questions = SITE.fetch('questions', fromdate=seconds_lm, todate=seconds_td)
#       4 questions
#
# ~\anaconda3\lib\site-packages\stackapi\stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     210                 code = response["error_name"]
#     211                 message = response["error_message"]
# --> 212                 raise StackAPIError(self._previous_call, error, code, message)
#     213             except KeyError:
#     214                 pass  # This means there is no error
#
# ...

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', fromdate=seconds_lm, todate=seconds_td)
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 286,
#  'total': 0,
#  'items': [{'owner': {'reputation': 83641,
#     'user_id': 637853,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/72baa38005eb8de126b2dd2e6fa1d660?s=256&d=identicon&r=PG',
#     'display_name': 'Thomas',
#     'link': 'https://stackoverflow.com/users/637853/thomas'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1642002324,
#    'last_edit_date': 1642002324,
#    'creation_date': 1641998618,
#    'answer_id': 70683524,
#    'question_id': 70682440,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 17120,
#     'user_id': 3485434,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://i.stack.imgur.com/7ZhrH.jpg?s=256&g=1',
#     'display_name': 'Prophet',
#     'link': 'https://stackoverflow.com/users/3485434/prophet'},
# ...

# %% [markdown]
# Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=int(datetime(2021,12,6,0,0).timestamp()), todate=seconds_td, tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 294,
#  'total': 0,
#  'items': [{'tags': ['python', 'django', 'web', 'web-applications'],
#    'owner': {'reputation': 71,
#     'user_id': 7480753,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/LpOGG.jpg?s=256&g=1',
#     'display_name': 'Abdul Halim Chowdhury',
#     'link': 'https://stackoverflow.com/users/7480753/abdul-halim-chowdhury'},
#    'is_answered': False,
#    'view_count': 30,
#    'answer_count': 1,
#    'score': 7,
#    'last_activity_date': 1638877807,
#    'creation_date': 1638877324,
#    'question_id': 70259507,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70259507/how-to-make-media-files-url-restricted-to-the-unauthenticated-users-in-django',
#    'title': 'How to make media file&#39;s URL restricted to the unauthenticated users in Django?'},
#   {'tags': ['python', 'pandas', 'apriori'],
# ...

# %%
data = pd.DataFrame(questions['items'])
data.value_counts('score')
# Out:
# score
# 0    246
# 1    202
# 2     40
# 3      7
# 4      4
# 7      1
# dtype: int64

# %%
#The first comment in the list of items is the comment with the hiest score of 7, so I am assuming that it is the most voted question
questions['items'][0]
# Out:
# {'tags': ['python', 'django', 'web', 'web-applications'],
#  'owner': {'reputation': 71,
#   'user_id': 7480753,
#   'user_type': 'registered',
#   'profile_image': 'https://i.stack.imgur.com/LpOGG.jpg?s=256&g=1',
#   'display_name': 'Abdul Halim Chowdhury',
#   'link': 'https://stackoverflow.com/users/7480753/abdul-halim-chowdhury'},
#  'is_answered': False,
#  'view_count': 30,
#  'answer_count': 1,
#  'score': 7,
#  'last_activity_date': 1638877807,
#  'creation_date': 1638877324,
#  'question_id': 70259507,
#  'content_license': 'CC BY-SA 4.0',
#  'link': 'https://stackoverflow.com/questions/70259507/how-to-make-media-files-url-restricted-to-the-unauthenticated-users-in-django',
#  'title': 'How to make media file&#39;s URL restricted to the unauthenticated users in Django?'}

# %% [markdown]
# Question 3: Find the answers with id 6784 and 6473.

# %%
data_answ = pd.DataFrame(answers['items'])
data_answ
# Out:
#                                                  owner  is_accepted  score  \
# 0    {'reputation': 1, 'user_id': 17613942, 'user_t...        False      0
# 1    {'reputation': 86, 'user_id': 5514131, 'user_t...        False      0
# 2    {'reputation': 430, 'user_id': 6478501, 'user_...        False      0
# 3    {'reputation': 1, 'user_id': 17614042, 'user_t...        False      0
# 4    {'reputation': 6688, 'user_id': 13014172, 'use...        False      0
# ..                                                 ...          ...    ...
# 495  {'reputation': 94015, 'user_id': 9097906, 'use...        False      0
# 496  {'reputation': 1, 'user_id': 17603039, 'user_t...        False      0
# 497  {'reputation': 1, 'user_id': 17497608, 'user_t...        False      0
# 498  {'reputation': 53, 'user_id': 3452939, 'user_t...        False      0
# 499  {'reputation': 187, 'user_id': 4706045, 'user_...         True      0
#
#      last_activity_date  last_edit_date  creation_date  answer_id  \
# ...

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', ids=[6784,6473])
answers['items']
# Out:
# [{'owner': {'reputation': 29899,
#    'user_id': 758,
#    'user_type': 'registered',
#    'accept_rate': 77,
#    'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#    'display_name': 'Mark Renouf',
#    'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#   'is_accepted': False,
#   'score': 0,
#   'last_activity_date': 1218291583,
#   'creation_date': 1218291583,
#   'answer_id': 6784,
#   'question_id': 6778,
#   'content_license': 'CC BY-SA 2.5'}]

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', ids=[6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 292,
#  'total': 0,
#  'items': []}
